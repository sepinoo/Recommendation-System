# %%
import pandas as pd

# %%
df = pd.read_excel('C:\\Users\\f\\Downloads\\14010929_1.xlsx')

# %%
df
# Out:
#      Product_Code                                       ProductTitle  Count
# 0             808                              کشمش 100 گرمي  گلستان   4721
# 1             809                               کشمش 300 گرمي گلستان   5368
# 2            1086             آجيل مخلوط چهار مغز شور 30 گرمي گلستان   9885
# 3            2904                               آويشن 45 گرمي گلستان   3527
# 4            2896                          ادويه کاري 80 گرمي گلستان   4016
# ..            ...                                                ...    ...
# 528           383           لوبيا قرمز  450 گرمي ( استند آپ ) گلستان   4372
# 529           384           لوبيا قرمز 900 گرمي ( استند آپ )  گلستان   3819
# 530          1063           مغز تخمه آفتابگردان سرکه نمکي 40 گرمي گل   4244
# 531          1911               هاتي نودل 77 گرمي 5 عددي با طعم گوشت  10610
# 532          1905  هاتي‌ نودل 77 گرمي 5 عددي با طعم مرغ(جايزه‌دار...  10739
#
# [533 rows x 3 columns]

# %%
list = []
list_bad = []
for i in range(len(df)):
    if df['Count'][i] >530:
        list.append(df['Product_Code'][i])
        
    else: 
        list_bad.append(df['Product_Code'][i])

# %%
len(list)
# Out:
# 357

# %%
list
# Out:
# [808,
#  809,
#  1086,
#  2904,
#  2896,
#  2898,
#  1688,
#  3044,
#  3014,
#  3015,
#  3030,
#  1644,
#  1604,
#  1522,
#  1521,
#  2609,
#  2323,
#  1408,
#  238,
#  2230,
#  2850,
#  558,
#  2018,
#  495,
#  496,
#  1605,
#  2945,
#  642,
#  418,
#  420,
#  1775,
#  1773,
#  1080,
#  1062,
#  2785,
#  380,
#  1941,
#  2889,
#  1903,
#  1904,
#  819,
#  3033,
#  1763,
#  722,
#  732,
#  1806,
#  1802,
#  1812,
#  1511,
#  2520,
#  1596,
#  224,
#  218,
#  207,
#  1524,
#  2931,
#  1611,
#  137,
#  2114,
#  2111,
#  2853,
#  641,
#  2846,
#  294,
#  284,
#  1943,
#  1469,
#  2034,
#  498,
#  497,
#  655,
#  1772,
#  1777,
#  2852,
#  1439,
#  1770,
#  667,
#  379,
#  1901,
#  1912,
#  1913,
#  1906,
#  657,
#  1933,
#  2911,
#  3116,
#  1048,
#  1686,
#  1630,
#  2903,
#  2040,
#  484,
#  1764,
#  1897,
#  788,
#  764,
#  729,
#  790,
#  1807,
#  1844,
#  2855,
#  2469,
#  1685,
#  1856,
#  1620,
#  1608,
#  1575,
#  2253,
#  2912,
#  2017,
#  2906,
#  1647,
#  1648,
#  2899,
# ...

# %%
dff = pd.DataFrame({'products':list})

# %%
dff.to_csv('products.csv')

# %%
df['ProductTitle'][df['Product_Code']==list[3]]
# Out:
# 3    آويشن 45 گرمي گلستان
# Name: ProductTitle, dtype: object

# %%
df['Count'][df['Product_Code']==list[3]]
# Out:
# 3    3527
# Name: Count, dtype: int64
